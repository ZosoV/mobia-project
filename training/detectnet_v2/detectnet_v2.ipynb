# %% [markdown]
# # Object Detection using TAO DetectNet_v2
#
# Transfer learning is the process of transferring learned features from one application to another. It is a commonly used training technique where you use a model trained on one task and re-train to use it on a different task.
#
# Train Adapt Optimize (TAO) Toolkit  is a simple and easy-to-use Python based AI toolkit for taking purpose-built AI models and customizing them with users' own data.
#
# <img align="center" src="https://developer.nvidia.com/sites/default/files/akamai/embedded-transfer-learning-toolkit-software-stack-1200x670px.png" width="1080">

# %% [markdown]
# ## Learning Objectives
# In this notebook, you will learn how to leverage the simplicity and convenience of TAO to:
#
# * Take a pretrained resnet18 model and train a ResNet-18 DetectNet_v2 model on the KITTI dataset
# * Prune the trained detectnet_v2 model
# * Retrain the pruned model to recover lost accuracy
# * Export the pruned model
# * Quantize the pruned model using QAT
# * Run Inference on the trained model
# * Export the pruned, quantized and retrained model to a .etlt file for deployment to DeepStream
# * Run inference on the exported. etlt model to verify deployment using TensorRT
#
# ### Table of Contents
#
# This notebook shows an example usecase of Object Detection using DetectNet_v2 in the Train Adapt Optimize (TAO) Toolkit.
#
# 0. [Set up env variables and map drives](#head-0)
# 1. [Install the TAO Launcher](#head-1)
# 1. [Prepare dataset and pre-trained model](#head-2)
#     1. [Download the dataset](#head-2-1)
#     1. [Verify downloaded dataset](#head-2-2)
#     1. [Prepare tfrecords from kitti format dataset](#head-2-3)
#     2. [Download pre-trained model](#head-2-4)
# 2. [Provide training specification](#head-3)
# 3. [Run TAO training](#head-4)
# 4. [Evaluate trained models](#head-5)
# 5. [Prune trained models](#head-6)
# 6. [Retrain pruned models](#head-7)
# 7. [Evaluate retrained model](#head-8)
# 8. [Visualize inferences](#head-9)
# 9. [Model Export](#head-10)
#     1. [Int8 Optimization](#head-10-1)
#     2. [Generate TensorRT engine](#head-10-2)
# 10. [Verify Deployed Model](#head-11)
#     1. [Inference using TensorRT engine](#head-11-1)
# 11. [QAT workflow](#head-12)
#     1. [Convert pruned model to QAT and retrain](#head-12-1)
#     2. [Evaluate QAT converted model](#head-12-2)
#     3. [Export QAT trained model to int8](#head-12-3)
#     4. [Evaluate a QAT trained model using the exported TensorRT engine](#head-12-4)
#     5. [Inference using QAT engine](#head-12-5)

# %% [markdown]
# ## 0. Set up env variables and map drives <a class="anchor" id="head-0"></a>
# When using the purpose-built pretrained models from NGC, please make sure to set the `$KEY` environment variable to the key as mentioned in the model overview. Failing to do so, can lead to errors when trying to load them as pretrained models.
#
# The following notebook requires the user to set an env variable called the `$LOCAL_PROJECT_DIR` as the path to the users workspace. Please note that the dataset to run this notebook is expected to reside in the `$LOCAL_PROJECT_DIR/data`, while the TAO experiment generated collaterals will be output to `$LOCAL_PROJECT_DIR/detectnet_v2`. More information on how to set up the dataset and the supported steps in the TAO workflow are provided in the subsequent cells.
#
# *Note: Please make sure to remove any stray artifacts/files from the `$USER_EXPERIMENT_DIR` or `$DATA_DOWNLOAD_DIR` paths as mentioned below, that may have been generated from previous experiments. Having checkpoint files etc may interfere with creating a training graph for a new experiment.*
#
# *Note: This notebook currently is by default set up to run training using 1 GPU. To use more GPU's please update the env variable `$NUM_GPUS` accordingly*

# %%
# Setting up env variables for cleaner command line commands.
import os

# %env KEY=tlt_encode
# %env NUM_GPUS=1
# %env USER_EXPERIMENT_DIR=/workspace/tao-experiments/detectnet_v2
# %env DATA_DOWNLOAD_DIR=/workspace/tao-experiments/data

# Set this path if you don't run the notebook from the samples directory.
# %env NOTEBOOK_ROOT=~/tao-samples/detectnet_v2

# Please define this local project directory that needs to be mapped to the TAO docker session.
# The dataset expected to be present in $LOCAL_PROJECT_DIR/data, while the results for the steps
# in this notebook will be stored at $LOCAL_PROJECT_DIR/detectnet_v2
# !PLEASE MAKE SURE TO UPDATE THIS PATH!.

os.environ["LOCAL_PROJECT_DIR"] = "/home/zosov/workspace/mobia-job/training/"

os.environ["LOCAL_DATA_DIR"] = os.path.join(
    os.getenv("LOCAL_PROJECT_DIR", os.getcwd()),
    "data"
)
os.environ["LOCAL_EXPERIMENT_DIR"] = os.path.join(
    os.getenv("LOCAL_PROJECT_DIR", os.getcwd()),
    "detectnet_v2"
)

# The sample spec files are present in the same path as the downloaded samples.
os.environ["LOCAL_SPECS_DIR"] = os.path.join(
    os.getenv("NOTEBOOK_ROOT", os.getcwd()),
    "specs"
)
# %env SPECS_DIR=/workspace/tao-experiments/detectnet_v2/specs

# Showing list of specification files.
# !ls -rlt $LOCAL_SPECS_DIR
# Out:
# env: KEY=tlt_encode
# env: NUM_GPUS=1
# env: USER_EXPERIMENT_DIR=/workspace/tao-experiments/detectnet_v2
# env: DATA_DOWNLOAD_DIR=/workspace/tao-experiments/data
# env: SPECS_DIR=/workspace/tao-experiments/detectnet_v2/specs
# total 40
# -rw-r--r-- 1 zosov zosov 2445 Apr  7 08:30 detectnet_v2_inference_kitti_etlt_qat.txt
# -rw-r--r-- 1 zosov zosov 2436 Apr  7 08:30 detectnet_v2_inference_kitti_etlt.txt
# -rw-r--r-- 1 zosov zosov 5539 Apr  7 08:30 detectnet_v2_train_resnet18_kitti.txt
# -rw-r--r-- 1 zosov zosov  310 Apr  7 08:30 detectnet_v2_tfrecords_kitti_trainval.txt
# -rw-r--r-- 1 zosov zosov 5620 Apr  7 08:30 detectnet_v2_retrain_resnet18_kitti_qat.txt
# -rw-r--r-- 1 zosov zosov 5557 Apr  7 08:30 detectnet_v2_retrain_resnet18_kitti.txt
# -rw-r--r-- 1 zosov zosov 2406 Apr  7 08:30 detectnet_v2_inference_kitti_tlt.txt

# %% [markdown]
# The cell below maps the project directory on your local host to a workspace directory in the TAO docker instance, so that the data and the results are mapped from in and out of the docker. For more information please refer to the [launcher instance](https://docs.nvidia.com/tao/tao-toolkit/tao_launcher.html) in the user guide.
#
# When running this cell on AWS, update the drive_map entry with the dictionary defined below, so that you don't have permission issues when writing data into folders created by the TAO docker.
#
# ```json
# drive_map = {
#     "Mounts": [
#             # Mapping the data directory
#             {
#                 "source": os.environ["LOCAL_PROJECT_DIR"],
#                 "destination": "/workspace/tao-experiments"
#             },
#             # Mapping the specs directory.
#             {
#                 "source": os.environ["LOCAL_SPECS_DIR"],
#                 "destination": os.environ["SPECS_DIR"]
#             },
#         ],
#     "DockerOptions": {
#         "user": "{}:{}".format(os.getuid(), os.getgid())
#     }
# }
# ```

# %%
# Mapping up the local directories to the TAO docker.
import json
mounts_file = os.path.expanduser("~/.tao_mounts.json")

# Define the dictionary with the mapped drives
drive_map = {
    "Mounts": [
        # Mapping the data directory
        {
            "source": os.environ["LOCAL_PROJECT_DIR"],
            "destination": "/workspace/tao-experiments"
        },
        # Mapping the specs directory.
        {
            "source": os.environ["LOCAL_SPECS_DIR"],
            "destination": os.environ["SPECS_DIR"]
        },
    ]
}

# Writing the mounts file.
with open(mounts_file, "w") as mfile:
    json.dump(drive_map, mfile, indent=4)

# %%
# !cat ~/.tao_mounts.json
# Out:
# {
#     "Mounts": [
#         {
#             "source": "/home/zosov/workspace/mobia-job/training/",
#             "destination": "/workspace/tao-experiments"
#         },
#         {
#             "source": "/home/zosov/workspace/mobia-job/training/detectnet_v2/specs",
#             "destination": "/workspace/tao-experiments/detectnet_v2/specs"
#         }
#     ]
# }

# %% [markdown]
# ## 1. Install the TAO launcher <a class="anchor" id="head-1"></a>
# The TAO launcher is a python package distributed as a python wheel listed in the `nvidia-pyindex` python index. You may install the launcher by executing the following cell.
#
# Please note that TAO Toolkit recommends users to run the TAO launcher in a virtual env with python 3.6.9. You may follow the instruction in this [page](https://virtualenvwrapper.readthedocs.io/en/latest/install.html) to set up a python virtual env using the `virtualenv` and `virtualenvwrapper` packages. Once you have setup virtualenvwrapper, please set the version of python to be used in the virtual env by using the `VIRTUALENVWRAPPER_PYTHON` variable. You may do so by running
#
# ```sh
# export VIRTUALENVWRAPPER_PYTHON=/path/to/bin/python3.x
# ```
# where x >= 6 and <= 8
#
# We recommend performing this step first and then launching the notebook from the virtual environment. In addition to installing TAO python package, please make sure of the following software requirements:
# * python >=3.6.9 < 3.8.x
# * docker-ce > 19.03.5
# * docker-API 1.40
# * nvidia-container-toolkit > 1.3.0-1
# * nvidia-container-runtime > 3.4.0-1
# * nvidia-docker2 > 2.5.0-1
# * nvidia-driver > 455+
#
#
# NOTE: if you already have the pretrained model this step is not necessary
# Once you have installed the pre-requisites, please log in to the docker registry nvcr.io by following the command below
#
# ```sh
# docker login nvcr.io
# ```
#
# You will be triggered to enter a username and password. The username is `$oauthtoken` and the password is the API key generated from `ngc.nvidia.com`. Please follow the instructions in the [NGC setup guide](https://docs.nvidia.com/ngc/ngc-overview/index.html#generating-api-key) to generate your own API key.

# %%
# SKIP this step IF you have already installed the TAO launcher wheel.
# !pip install nvidia-pyindex
# !pip install nvidia-tao
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nvidia-pyindex in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (1.0.9)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nvidia-tao in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (0.1.21)
# Requirement already satisfied: certifi==2020.6.20 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (2020.6.20)
# Requirement already satisfied: urllib3==1.25.10 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (1.25.10)
# Requirement already satisfied: tabulate==0.8.7 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (0.8.7)
# Requirement already satisfied: websocket-client==0.57.0 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (0.57.0)
# Requirement already satisfied: idna==2.10 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (2.10)
# Requirement already satisfied: requests==2.24.0 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (2.24.0)
# Requirement already satisfied: six==1.15.0 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (1.15.0)
# Requirement already satisfied: docker==4.3.1 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (4.3.1)
# Requirement already satisfied: chardet==3.0.4 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (3.0.4)
# Requirement already satisfied: docker-pycreds==0.4.0 in /home/zosov/anaconda3/envs/mobia-train/lib/python3.7/site-packages (from nvidia-tao) (0.4.0)

# %%
# View the versions of the TAO launcher
# !tao info
# Out:
# Configuration of the TAO Toolkit Instance
# dockers: ['nvidia/tao/tao-toolkit-tf', 'nvidia/tao/tao-toolkit-pyt', 'nvidia/tao/tao-toolkit-lm']
# format_version: 2.0
# toolkit_version: 3.22.02
# published_date: 02/28/2022

# %% [markdown]
# ## 2. Prepare dataset and pre-trained model <a class="anchor" id="head-2"></a>

# %% [markdown]
# We will be using the kitti object detection dataset for this example. To find more details, please visit http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d. Please download both, the left color images of the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_image_2.zip) and, the training labels for the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_label_2.zip), and place the zip files in `$LOCAL_DATA_DIR`
#
# The data will then be extracted to have
# * training images in `$LOCAL_DATA_DIR/training/image_2`
# * training labels in `$LOCAL_DATA_DIR/training/label_2`
# * testing images in `$LOCAL_DATA_DIR/testing/image_2`
#
# You may use this notebook with your own dataset as well. To use this example with your own dataset, please follow the same directory structure as mentioned below.
#
# *Note: There are no labels for the testing images, therefore we use it just to visualize inferences for the trained model.*

# %% [markdown]
# ### A. Download the dataset <a class="anchor" id="head-2-1"></a>
# Once you have gotten the download links in your email, please populate them in place of the `KITTI_IMAGES_DOWNLOAD_URL` and the `KITTI_LABELS_DOWNLOAD_URL`. This next cell, will download the data and place in `$LOCAL_DATA_DIR`

# %%
import os
# !mkdir -p $LOCAL_DATA_DIR
os.environ["URL_IMAGES"]="https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip"
# !if [ ! -f $LOCAL_DATA_DIR/data_object_image_2.zip ]; then wget $URL_IMAGES -O $LOCAL_DATA_DIR/data_object_image_2.zip; else echo "image archive already downloaded"; fi 
os.environ["URL_LABELS"]="https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip"
# !if [ ! -f $LOCAL_DATA_DIR/data_object_label_2.zip ]; then wget $URL_LABELS -O $LOCAL_DATA_DIR/data_object_label_2.zip; else \ echo "label archive already downloaded"; fi
# Out:
# --2022-04-07 10:51:06--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.169.45
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.169.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12569945557 (12G) [application/zip]
# Saving to: ‘/home/zosov/workspace/mobia-job/training/data/data_object_image_2.zip’
#
# /home/zosov/workspa 100%[===================>]  11.71G  6.66MB/s    in 20m 36s
#
# 2022-04-07 11:11:43 (9.70 MB/s) - ‘/home/zosov/workspace/mobia-job/training/data/data_object_image_2.zip’ saved [12569945557/12569945557]
#
# --2022-04-07 11:11:43--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.171.109
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.171.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5601213 (5.3M) [application/zip]
# Saving to: ‘/home/zosov/workspace/mobia-job/training/data/data_object_label_2.zip’
#
# /home/zosov/workspa 100%[===================>]   5.34M  3.39MB/s    in 1.6s
#
# 2022-04-07 11:11:46 (3.39 MB/s) - ‘/home/zosov/workspace/mobia-job/training/data/data_object_label_2.zip’ saved [5601213/5601213]

# %% [markdown]
# ### B. Verify downloaded dataset <a class="anchor" id="head-2-2"></a>

# %%
# Check the dataset is present
# !if [ ! -f $LOCAL_DATA_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
# !if [ ! -f $LOCAL_DATA_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi
# Out:
# Found Image zip file.
# Found Labels zip file.

# %%
# This may take a while: verify integrity of zip files 
# !sha256sum $LOCAL_DATA_DIR/data_object_image_2.zip | cut -d ' ' -f 1 | grep -xq '^351c5a2aa0cd9238b50174a3a62b846bc5855da256b82a196431d60ff8d43617$' ; \
if test $? -eq 0; then echo "images OK"; else echo "images corrupt, redownload!" && rm -f $LOCAL_DATA_DIR/data_object_image_2.zip; fi 
# !sha256sum $LOCAL_DATA_DIR/data_object_label_2.zip | cut -d ' ' -f 1 | grep -xq '^4efc76220d867e1c31bb980bbf8cbc02599f02a9cb4350effa98dbb04aaed880$' ; \
if test $? -eq 0; then echo "labels OK"; else echo "labels corrupt, redownload!" && rm -f $LOCAL_DATA_DIR/data_object_label_2.zip; fi
# Out:
# images OK
# labels OK

# %%
# unpack downloaded datasets to $DATA_DOWNLOAD_DIR.
# The training images will be under $DATA_DOWNLOAD_DIR/training/image_2 and 
# labels will be under $DATA_DOWNLOAD_DIR/training/label_2.
# The testing images will be under $DATA_DOWNLOAD_DIR/testing/image_2.
# !unzip -u $LOCAL_DATA_DIR/data_object_image_2.zip -d $LOCAL_DATA_DIR
# !unzip -u $LOCAL_DATA_DIR/data_object_label_2.zip -d $LOCAL_DATA_DIR
# Out:
# Archive:  /home/zosov/workspace/mobia-job/training/data/data_object_image_2.zip
#    creating: /home/zosov/workspace/mobia-job/training/data/training/image_2/
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002480.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005952.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000709.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000814.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006192.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006017.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002731.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005295.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005347.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005326.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005713.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007000.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004353.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003969.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001973.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001440.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007083.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000166.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004479.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003732.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003998.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001768.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003576.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006565.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001665.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001604.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002037.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006729.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006666.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001928.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007175.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001303.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002893.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006514.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002445.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005183.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006688.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001083.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005950.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000649.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005488.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001456.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005091.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000946.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003063.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003944.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000228.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005904.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002274.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005069.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006011.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002942.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003887.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006863.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006324.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002627.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002437.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002894.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004121.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003942.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003876.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000671.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004735.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003837.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003218.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006476.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000913.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000921.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007144.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006205.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007121.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000549.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004275.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002795.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003670.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007140.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004100.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007188.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007235.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002612.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006289.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002406.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005755.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004368.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005192.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000163.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001229.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004036.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006216.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001394.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000894.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003293.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002474.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006360.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007271.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004064.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001038.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003072.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006133.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002007.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006845.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004852.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006323.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003222.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004169.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006738.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005628.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001842.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004363.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007115.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001598.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000147.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001024.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004356.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001504.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002261.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005283.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006850.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006615.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000967.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003628.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001879.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005981.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000929.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004089.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000466.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002493.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002941.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001475.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004939.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006358.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005104.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002860.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006759.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000791.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001465.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000162.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005484.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005231.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006317.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005590.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003402.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003440.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001526.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007439.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003542.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005340.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006607.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000247.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004592.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001929.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003709.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003556.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003442.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000412.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005984.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007156.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001678.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005978.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006532.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005553.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004515.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005211.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004158.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006331.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002689.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002311.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007357.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005229.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006544.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005944.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001020.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005582.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000965.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000313.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002161.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000969.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002599.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006832.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003783.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002750.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002087.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003324.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004967.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001766.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005847.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005201.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005237.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001657.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005427.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003299.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002163.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005869.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003650.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006310.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007288.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003185.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005656.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005907.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000689.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003796.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004860.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003594.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001527.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000943.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003140.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001450.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004294.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006190.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001340.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005109.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002241.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005531.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005442.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000284.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004080.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000795.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007278.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003787.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004934.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004554.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003097.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004975.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003426.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003681.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003313.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007070.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002031.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002128.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006908.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002428.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001580.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003455.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002525.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004413.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003408.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000221.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000535.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004300.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004682.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006956.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001900.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000861.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006712.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001833.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006415.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006404.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000959.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002206.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002147.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002700.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003564.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002518.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006109.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005111.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004653.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002012.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000734.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006507.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002726.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001339.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004212.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007037.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003928.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002506.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001529.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001953.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001071.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001353.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002370.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000952.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005131.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001869.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000842.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000520.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004659.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002072.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001767.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005527.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000124.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004165.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006746.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007021.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001365.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004278.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006655.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005164.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001898.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005608.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002073.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003991.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000203.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004728.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001266.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001044.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000578.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005169.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003677.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006093.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005365.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005140.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006604.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006095.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007466.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006423.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003358.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005547.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002532.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003970.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004282.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001176.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003031.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003799.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001758.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001674.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002652.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006942.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005279.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005188.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007416.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003210.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000272.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003752.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000192.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005783.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002160.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003879.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003654.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003040.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006990.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004050.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005519.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003706.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001037.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004639.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003617.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001005.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001231.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006945.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002725.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006100.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003826.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000740.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002402.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006029.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004177.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005802.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005150.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004807.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001940.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002737.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005636.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000707.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001839.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001194.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005649.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002338.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004210.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000306.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000928.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007265.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006285.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001208.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001806.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005909.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004636.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006714.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000016.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001956.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003802.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000937.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002452.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005016.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004598.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001762.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005077.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000729.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005750.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003167.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000551.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004801.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003444.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004331.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003470.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004151.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001178.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007219.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002318.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000701.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001622.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002507.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003531.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006502.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000077.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004954.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005256.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000103.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006380.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000828.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002786.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000606.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000188.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005507.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000151.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002415.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000743.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006275.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002130.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005021.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005764.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004582.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005982.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002531.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005299.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004657.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006234.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005481.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000212.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005003.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000493.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007358.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004271.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000902.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002443.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001204.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002329.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001783.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000878.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006431.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006157.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006241.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007246.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005724.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005337.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006526.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006504.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001388.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000410.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005101.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007161.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000513.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004710.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002503.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004843.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001782.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005311.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003461.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003574.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000964.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000146.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000459.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006104.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005307.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004422.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001117.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000507.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002174.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001919.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004242.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005865.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002141.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005027.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003067.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001874.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006251.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004780.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000169.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002590.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005880.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001563.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004460.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005937.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000492.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006529.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004611.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005078.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001052.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000879.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001011.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000453.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000214.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001489.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005429.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000956.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002494.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004143.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007067.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001551.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007263.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006916.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003305.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000072.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001712.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002470.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001943.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000245.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004078.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007325.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001685.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005186.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001424.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004288.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007107.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001788.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006950.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005808.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000587.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001596.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001298.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003084.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004925.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/007322.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006509.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006576.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000516.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000573.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000773.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003766.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000035.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000557.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004021.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/004200.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003311.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005196.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000275.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002302.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001219.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/003627.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001952.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002838.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/001447.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002301.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006816.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/002098.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/000922.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/005883.png
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/image_2/006810.png
# ...
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000930.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003824.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002210.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006384.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006895.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005363.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001062.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005196.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007292.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000378.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005870.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002392.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004312.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003889.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000672.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006946.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003941.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005020.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000880.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004019.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001298.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005130.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004292.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001157.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004590.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000949.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005460.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005681.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006498.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003450.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002917.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003416.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003110.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004479.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003641.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004574.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003894.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000915.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001883.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006140.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005843.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001394.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002465.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001594.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007432.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004802.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002857.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003499.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006385.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002035.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007448.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003571.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006407.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001281.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006241.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005800.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001612.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003903.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002404.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006251.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006406.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001544.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003251.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006844.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007447.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001585.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002885.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002342.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006862.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001125.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005619.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005003.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006145.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002762.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000931.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005798.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006798.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006811.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001899.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000568.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001329.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007458.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000849.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004117.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003545.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003711.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000602.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001254.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003070.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003211.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003445.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006530.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002672.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005759.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006692.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005022.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002803.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007315.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004939.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001839.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003329.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005126.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007134.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002640.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005978.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002548.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000472.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004831.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004688.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000504.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005558.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002629.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007154.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006763.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003852.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006750.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000889.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005075.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002346.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005027.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005320.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006186.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000731.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006136.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001915.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005965.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004288.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000830.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003720.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004373.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007385.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006528.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005567.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003068.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001396.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002127.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003740.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002928.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005309.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004123.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004618.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000295.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001089.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007121.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007043.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003204.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000566.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005153.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005255.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000639.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003104.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005909.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003362.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006327.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006531.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004583.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005928.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001282.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006347.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001629.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002889.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004964.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005101.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004359.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002288.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/003324.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006875.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005407.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/007414.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002625.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/000730.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/005747.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001455.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/006386.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002777.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/001730.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002740.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/002057.txt
#  extracting: /home/zosov/workspace/mobia-job/training/data/training/label_2/004455.txt

# %%
# verify
import os

DATA_DIR = os.environ.get('LOCAL_DATA_DIR')
num_training_images = len(os.listdir(os.path.join(DATA_DIR, "training/image_2")))
num_training_labels = len(os.listdir(os.path.join(DATA_DIR, "training/label_2")))
num_testing_images = len(os.listdir(os.path.join(DATA_DIR, "testing/image_2")))
print("Number of images in the train/val set. {}".format(num_training_images))
print("Number of labels in the train/val set. {}".format(num_training_labels))
print("Number of images in the test set. {}".format(num_testing_images))
# Out:
# Number of images in the train/val set. 7481
# Number of labels in the train/val set. 7481
# Number of images in the test set. 7518

# %%
# Sample kitti label.
# !cat $LOCAL_DATA_DIR/training/label_2/000110.txt
# Out:
# Car 0.27 0 2.50 862.65 129.39 1241.00 304.96 1.73 1.74 4.71 5.50 1.30 8.19 3.07
# Car 0.68 3 -0.76 1184.97 141.54 1241.00 187.84 1.52 1.60 4.42 22.39 0.48 24.57 -0.03
# Car 0.00 1 1.73 346.64 175.63 449.93 248.90 1.58 1.76 4.18 -5.13 1.67 17.86 1.46
# Car 0.00 0 1.75 420.44 170.72 540.83 256.12 1.65 1.88 4.45 -2.78 1.64 16.30 1.58
# Car 0.00 0 -0.35 815.59 143.96 962.82 198.54 1.90 1.78 4.72 10.19 0.90 26.65 0.01
# Car 0.00 1 -2.09 966.10 144.74 1039.76 182.96 1.80 1.65 3.55 19.49 0.49 35.99 -1.59
# Van 0.00 2 -2.07 1084.26 132.74 1173.25 177.89 2.11 1.75 4.31 26.02 0.24 36.41 -1.45
# Car 0.00 2 -2.13 1004.98 144.16 1087.13 178.96 1.64 1.70 3.91 21.91 0.30 36.47 -1.59
# Car 0.00 2 1.77 407.73 178.44 487.07 230.28 1.55 1.71 4.50 -5.35 1.76 24.13 1.55
# Car 0.00 1 1.45 657.19 166.33 702.65 198.71 1.50 1.71 4.44 3.39 1.22 35.96 1.55
# Car 0.00 1 -1.46 599.30 171.76 631.96 197.12 1.58 1.71 3.75 0.39 1.54 47.31 -1.45
# Car 0.00 0 -1.02 557.79 165.74 591.61 181.27 1.66 1.65 4.45 -3.89 0.91 80.12 -1.07

# %% [markdown]
# ### C. Prepare tf records from kitti format dataset <a class="anchor" id="head-2-3"></a>
#
# * Update the tfrecords spec file to take in your kitti format dataset
# * Create the tfrecords using the detectnet_v2 dataset_convert
#
# *Note: TfRecords only need to be generated once.*

# %%
print("TFrecords conversion spec file for kitti training")
# !cat $LOCAL_SPECS_DIR/detectnet_v2_tfrecords_kitti_trainval.txt
# Out:
# TFrecords conversion spec file for kitti training
# kitti_config {
#   root_directory_path: "/workspace/tao-experiments/data/training"
#   image_dir_name: "image_2"
#   label_dir_name: "label_2"
#   image_extension: ".png"
#   partition_mode: "random"
#   num_partitions: 2
#   val_split: 14
#   num_shards: 10
# }
# image_directory_path: "/workspace/tao-experiments/data/training"

# %%
# Creating a new directory for the output tfrecords dump.
print("Converting Tfrecords for kitti trainval dataset")
# !mkdir -p $LOCAL_DATA_DIR/tfrecords && rm -rf $LOCAL_DATA_DIR/tfrecords/*
# !tao detectnet_v2 dataset_convert \
                  -d $SPECS_DIR/detectnet_v2_tfrecords_kitti_trainval.txt \
                  -o $DATA_DOWNLOAD_DIR/tfrecords/kitti_trainval/kitti_trainval
# Out:
# Converting Tfrecords for kitti trainval dataset
# 2022-04-07 11:57:27,166 [INFO] root: Registry: ['nvcr.io']
# 2022-04-07 11:57:27,283 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.21.11-tf1.15.4-py3
# 2022-04-07 11:57:27,334 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/zosov/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2022-04-07 16:57:42,397 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2022-04-07 16:57:42,398 [INFO] root: Instantiating a kitti converter
# 2022-04-07 16:57:42,398 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Creating output directory /workspace/tao-experiments/data/tfrecords/kitti_trainval
# 2022-04-07 16:57:42,398 [INFO] root: Generating partitions
# 2022-04-07 16:57:42,459 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 6434	Val: 1047
# 2022-04-07 16:57:42,459 [INFO] root: Num images in
# Train: 6434	Val: 1047
# 2022-04-07 16:57:42,459 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2022-04-07 16:57:42,459 [INFO] root: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2022-04-07 16:57:42,470 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2022-04-07 16:57:42,470 [INFO] root: Writing partition 0, shard 0
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/dataio/dataset_converter_lib.py:161: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# 2022-04-07 16:57:42,470 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/dataio/dataset_converter_lib.py:161: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# /usr/local/lib/python3.6/dist-packages/iva/detectnet_v2/dataio/kitti_converter_lib.py:297: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2022-04-07 16:57:42,874 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2022-04-07 16:57:42,874 [INFO] root: Writing partition 0, shard 1
# 2022-04-07 16:57:43,192 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2022-04-07 16:57:43,193 [INFO] root: Writing partition 0, shard 2
# 2022-04-07 16:57:43,443 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2022-04-07 16:57:43,444 [INFO] root: Writing partition 0, shard 3
# 2022-04-07 16:57:43,697 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2022-04-07 16:57:43,697 [INFO] root: Writing partition 0, shard 4
# 2022-04-07 16:57:43,963 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2022-04-07 16:57:43,963 [INFO] root: Writing partition 0, shard 5
# 2022-04-07 16:57:44,248 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2022-04-07 16:57:44,248 [INFO] root: Writing partition 0, shard 6
# 2022-04-07 16:57:44,512 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2022-04-07 16:57:44,512 [INFO] root: Writing partition 0, shard 7
# 2022-04-07 16:57:44,800 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2022-04-07 16:57:44,800 [INFO] root: Writing partition 0, shard 8
# 2022-04-07 16:57:45,077 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2022-04-07 16:57:45,077 [INFO] root: Writing partition 0, shard 9
# 2022-04-07 16:57:45,379 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'car': 4039
# b'truck': 144
# b'dontcare': 1520
# b'tram': 60
# b'pedestrian': 661
# b'cyclist': 216
# b'van': 424
# b'misc': 134
# b'person_sitting': 36
#
# 2022-04-07 16:57:45,379 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2022-04-07 16:57:45,379 [INFO] root: Writing partition 1, shard 0
# 2022-04-07 16:57:47,033 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2022-04-07 16:57:47,033 [INFO] root: Writing partition 1, shard 1
# 2022-04-07 16:57:48,802 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2022-04-07 16:57:48,802 [INFO] root: Writing partition 1, shard 2
# 2022-04-07 16:57:50,575 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2022-04-07 16:57:50,576 [INFO] root: Writing partition 1, shard 3
# 2022-04-07 16:57:52,267 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2022-04-07 16:57:52,267 [INFO] root: Writing partition 1, shard 4
# 2022-04-07 16:57:53,817 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2022-04-07 16:57:53,817 [INFO] root: Writing partition 1, shard 5
# 2022-04-07 16:57:55,498 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2022-04-07 16:57:55,498 [INFO] root: Writing partition 1, shard 6
# 2022-04-07 16:57:57,217 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2022-04-07 16:57:57,217 [INFO] root: Writing partition 1, shard 7
# 2022-04-07 16:57:58,975 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2022-04-07 16:57:58,975 [INFO] root: Writing partition 1, shard 8
# 2022-04-07 16:58:00,538 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2022-04-07 16:58:00,538 [INFO] root: Writing partition 1, shard 9
# 2022-04-07 16:58:02,254 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'car': 24703
# b'van': 2490
# b'dontcare': 9775
# b'misc': 839
# b'cyclist': 1411
# b'pedestrian': 3826
# b'truck': 950
# b'tram': 451
# b'person_sitting': 186
#
# 2022-04-07 16:58:02,254 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2022-04-07 16:58:02,254 [INFO] root: Cumulative object statistics
# 2022-04-07 16:58:02,255 [INFO] root: {
#     "car": 28742,
#     "truck": 1094,
#     "dontcare": 11295,
#     "tram": 511,
#     "pedestrian": 4487,
#     "cyclist": 1627,
#     "van": 2914,
#     "misc": 973,
#     "person_sitting": 222
# }
# 2022-04-07 16:58:02,255 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'car': 28742
# b'truck': 1094
# b'dontcare': 11295
# b'tram': 511
# b'pedestrian': 4487
# b'cyclist': 1627
# b'van': 2914
# b'misc': 973
# b'person_sitting': 222
#
# 2022-04-07 16:58:02,255 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'Car': b'car'
# b'Truck': b'truck'
# b'DontCare': b'dontcare'
# b'Tram': b'tram'
# b'Pedestrian': b'pedestrian'
# b'Cyclist': b'cyclist'
# b'Van': b'van'
# b'Misc': b'misc'
# b'Person_sitting': b'person_sitting'
# 2022-04-07 16:58:02,255 [INFO] root: Class map.
# Label in GT: Label in tfrecords file
# b'Car': b'car'
# b'Truck': b'truck'
# b'DontCare': b'dontcare'
# b'Tram': b'tram'
# b'Pedestrian': b'pedestrian'
# b'Cyclist': b'cyclist'
# b'Van': b'van'
# b'Misc': b'misc'
# b'Person_sitting': b'person_sitting'
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2022-04-07 16:58:02,255 [INFO] root: For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2022-04-07 16:58:02,256 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# 2022-04-07 16:58:02,256 [INFO] root: TFRecords generation complete.
# 2022-04-07 11:58:03,682 [INFO] tlt.components.docker_handler.docker_handler: Stopping container.

# %%
# !ls -rlt $LOCAL_DATA_DIR/tfrecords/kitti_trainval/
# Out:
# total 7136
# -rw-r--r-- 1 root root 102092 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 102734 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 101503 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 103417 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 103450 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 102268 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root  97308 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root  98016 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root  99755 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 105314 Apr  7 11:57 kitti_trainval-fold-000-of-002-shard-00009-of-00010
# -rw-r--r-- 1 root root 629863 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 630535 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 621514 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 618982 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 632148 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 615957 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 617775 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 633446 Apr  7 11:57 kitti_trainval-fold-001-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root 626815 Apr  7 11:58 kitti_trainval-fold-001-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 630366 Apr  7 11:58 kitti_trainval-fold-001-of-002-shard-00009-of-00010

# %% [markdown]
# ### D. Download pre-trained model <a class="anchor" id="head-2-4"></a>
# Download the correct pretrained model from the NGC model registry for your experiment. Please note that for DetectNet_v2, the input is expected to be 0-1 normalized with input channels in RGB order. Therefore, for optimum results please download model templates from `nvidia/tao/pretrained_detectnet_v2`. The templates are now organized as version strings. For example, to download a resnet18 model suitable for detectnet please resolve to the ngc object shown as `nvidia/tao/pretrained_detectnet_v2:resnet18`.
#
# All other models are in BGR order expect input preprocessing with mean subtraction and input channels. Using them as pretrained weights may result in suboptimal performance.
#
# You may also use this notebook with the following purpose-built pretrained models
# * [PeopleNet](https://ngc.nvidia.com/catalog/models/nvidia:tao:peoplenet)
# * [TrafficCamNet](https://ngc.nvidia.com/catalog/models/nvidia:tao:trafficcamnet)
# * [DashCamNet](https://ngc.nvidia.com/catalog/models/nvidia:tao:dashcamnet)
# * [FaceDetect-IR](https://ngc.nvidia.com/catalog/models/nvidia:tao:facedetectir)

# %%
# Installing NGC CLI on the local machine.
## Download and install
# %env CLI=ngccli_cat_linux.zip
# !mkdir -p $LOCAL_PROJECT_DIR/ngccli

# Remove any previously existing CLI installations
# !rm -rf $LOCAL_PROJECT_DIR/ngccli/*
# !wget "https://ngc.nvidia.com/downloads/$CLI" -P $LOCAL_PROJECT_DIR/ngccli
# !unzip -u "$LOCAL_PROJECT_DIR/ngccli/$CLI" -d $LOCAL_PROJECT_DIR/ngccli/
# !rm $LOCAL_PROJECT_DIR/ngccli/*.zip 
os.environ["PATH"]="{}/ngccli:{}".format(os.getenv("LOCAL_PROJECT_DIR", ""), os.getenv("PATH", ""))
# Out:
# env: CLI=ngccli_cat_linux.zip
# --2022-04-07 11:58:21--  https://ngc.nvidia.com/downloads/ngccli_cat_linux.zip
# Resolving ngc.nvidia.com (ngc.nvidia.com)... 13.227.26.128, 13.227.26.33, 13.227.26.56, ...
# Connecting to ngc.nvidia.com (ngc.nvidia.com)|13.227.26.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32588469 (31M) [application/zip]
# Saving to: ‘/home/zosov/workspace/mobia-job/training//ngccli/ngccli_cat_linux.zip’
#
# ngccli_cat_linux.zi 100%[===================>]  31.08M  10.8MB/s    in 2.9s
#
# 2022-04-07 11:58:24 (10.8 MB/s) - ‘/home/zosov/workspace/mobia-job/training//ngccli/ngccli_cat_linux.zip’ saved [32588469/32588469]
#
# Archive:  /home/zosov/workspace/mobia-job/training//ngccli/ngccli_cat_linux.zip
#   inflating: /home/zosov/workspace/mobia-job/training//ngccli/ngc
#  extracting: /home/zosov/workspace/mobia-job/training//ngccli/ngc.md5

# %%
# !echo $LOCAL_EXPERIMENT_DIR
# Out:
# /home/zosov/workspace/mobia-job/training/detectnet_v2

# %%
# List models available in the model registry.
# !ngc registry model list nvidia/tao/pretrained_detectnet_v2:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | vgg19 | 82.6  | 80    | 1     | V100  | 153.8 | 153.7 | UPLOA | Aug   |
# |       |       |       |       |       |       | 7 MB  | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | vgg16 | 82.2  | 80    | 1     | V100  | 113.2 | 113.2 | UPLOA | Aug   |
# |       |       |       |       |       |       | MB    | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | squee | 65.67 | 80    | 1     | V100  | 6.5   | 6.46  | UPLOA | Aug   |
# | zenet |       |       |       |       |       | MB    | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 82.7  | 80    | 1     | V100  | 294.5 | 294.5 | UPLOA | Aug   |
# | t50   |       |       |       |       |       | 3 MB  | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 77.04 | 80    | 1     | V100  | 170.6 | 170.6 | UPLOA | Jan   |
# | t34   |       |       |       |       | 5MB   | 5 MB  | D_COM | 28,   |
# |       |       |       |       |       |       |       | PLETE | 2022  |
# | resne | 79.0  | 80    | 1     | V100  | 89.0  | 89.02 | UPLOA | Aug   |
# | t18   |       |       |       |       |       | MB    | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | resne | 79.2  | 80    | 1     | V100  | 38.3  | 38.34 | UPLOA | Aug   |
# | t10   |       |       |       |       |       | MB    | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | mobil | 77.5  | 80    | 1     | V100  | 5.1   | 5.1   | UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 24,   |
# | v2    |       |       |       |       |       |       | PLETE | 2021  |
# | mobil | 79.5  | 80    | 1     | V100  | 13.4  | 13.37 | UPLOA | Aug   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 24,   |
# | v1    |       |       |       |       |       |       | PLETE | 2021  |
# | googl | 82.2  | 80    | 1     | V100  | 47.7  | 47.74 | UPLOA | Aug   |
# | enet  |       |       |       |       |       | MB    | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | effic | 77.11 | 80    | 1     | V100  | 16.9  | 16.9  | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b0 |       |       |       |       |       |       | PLETE | 2021  |
# | _swis |       |       |       |       |       |       |       |       |
# | h     |       |       |       |       |       |       |       |       |
# | effic | 77.11 | 80    | 1     | V100  | 16.9  | 16.9  | UPLOA | Aug   |
# | ientn |       |       |       |       |       | MB    | D_COM | 18,   |
# | et_b0 |       |       |       |       |       |       | PLETE | 2021  |
# | _relu |       |       |       |       |       |       |       |       |
# | darkn | 76.44 | 80    | 1     | V100  | 467.3 | 467.3 | UPLOA | Aug   |
# | et53  |       |       |       |       |       | 2 MB  | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# | darkn | 77.52 | 80    | 1     | V100  | 229.1 | 229.1 | UPLOA | Aug   |
# | et19  |       |       |       |       |       | 5 MB  | D_COM | 24,   |
# |       |       |       |       |       |       |       | PLETE | 2021  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# Create the target destination to download the model.
# !mkdir -p $LOCAL_EXPERIMENT_DIR/pretrained_resnet18/

# %%
# Download the pretrained model from NGC
# !ngc registry model download-version nvidia/tao/pretrained_detectnet_v2:resnet18 \
    --dest $LOCAL_EXPERIMENT_DIR/pretrained_resnet18
# Out:
# Downloaded 82.28 MB in 13s, Download speed: 6.32 MB/s
# ----------------------------------------------------
# Transfer id: pretrained_detectnet_v2_vresnet18 Download status: Completed.
# Downloaded local path: /home/zosov/workspace/mobia-job/training/detectnet_v2/pretrained_resnet18/pretrained_detectnet_v2_vresnet18
# Total files downloaded: 1
# Total downloaded size: 82.28 MB
# Started at: 2022-04-07 12:02:51.107391
# Completed at: 2022-04-07 12:03:04.127122
# Duration taken: 13s
# ----------------------------------------------------

# %%
# !ls -rlt $LOCAL_EXPERIMENT_DIR/pretrained_resnet18/pretrained_detectnet_v2_vresnet18
# Out:
# total 91160
# -rw------- 1 zosov zosov 93345248 Apr  7 12:03 resnet18.hdf5

# %% [markdown]
# ## 3. Provide training specification <a class="anchor" id="head-3"></a>
# * Tfrecords for the train datasets
#     * To use the newly generated tfrecords, update the dataset_config parameter in the spec file at `$SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt`
#     * Update the fold number to use for evaluation. In case of random data split, please use fold `0` only
#     * For sequence-wise split, you may use any fold generated from the dataset convert tool
# * Pre-trained models
# * Augmentation parameters for on the fly data augmentation
# * Other training (hyper-)parameters such as batch size, number of epochs, learning rate etc.

# %%
# !cat $LOCAL_SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt
# Out:
# random_seed: 42
# dataset_config {
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/data/tfrecords/kitti_trainval/*"
#     image_directory_path: "/workspace/tao-experiments/data/training"
#   }
#   image_extension: "png"
#   target_class_mapping {
#     key: "car"
#     value: "car"
#   }
#   target_class_mapping {
#     key: "cyclist"
#     value: "cyclist"
#   }
#   target_class_mapping {
#     key: "pedestrian"
#     value: "pedestrian"
#   }
#   target_class_mapping {
#     key: "person_sitting"
#     value: "pedestrian"
#   }
#   target_class_mapping {
#     key: "van"
#     value: "car"
#   }
#   validation_fold: 0
# }
# augmentation_config {
#   preprocessing {
#     output_image_width: 1248
#     output_image_height: 384
#     min_bbox_width: 1.0
#     min_bbox_height: 1.0
#     output_image_channel: 3
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     zoom_min: 1.0
#     zoom_max: 1.0
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
# postprocessing_config {
#   target_class_config {
#     key: "car"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.20000000298
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
#   target_class_config {
#     key: "cyclist"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
#   target_class_config {
#     key: "pedestrian"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00749999983236
#         dbscan_eps: 0.230000004172
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
# }
# model_config {
#   pretrained_model_file: "/workspace/tao-experiments/detectnet_v2/pretrained_resnet18/pretrained_detectnet_v2_vresnet18/resnet18.hdf5"
#   num_layers: 18
#   use_batch_norm: true
#   objective_set {
#     bbox {
#       scale: 35.0
#       offset: 0.5
#     }
#     cov {
#     }
#   }
#   arch: "resnet"
# }
# evaluation_config {
#   validation_period_during_training: 10
#   first_validation_epoch: 30
#   minimum_detection_ground_truth_overlap {
#     key: "car"
#     value: 0.699999988079
#   }
#   minimum_detection_ground_truth_overlap {
#     key: "cyclist"
#     value: 0.5
#   }
#   minimum_detection_ground_truth_overlap {
#     key: "pedestrian"
#     value: 0.5
#   }
#   evaluation_box_config {
#     key: "car"
#     value {
#       minimum_height: 20
#       maximum_height: 9999
#       minimum_width: 10
#       maximum_width: 9999
#     }
#   }
#   evaluation_box_config {
#     key: "cyclist"
#     value {
#       minimum_height: 20
#       maximum_height: 9999
#       minimum_width: 10
#       maximum_width: 9999
#     }
#   }
#   evaluation_box_config {
#     key: "pedestrian"
#     value {
#       minimum_height: 20
#       maximum_height: 9999
#       minimum_width: 10
#       maximum_width: 9999
#     }
#   }
#   average_precision_mode: INTEGRATE
# }
# cost_function_config {
#   target_classes {
#     name: "car"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 10.0
#     }
#   }
#   target_classes {
#     name: "cyclist"
#     class_weight: 8.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   target_classes {
#     name: "pedestrian"
#     class_weight: 4.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 10.0
#     }
#   }
#   enable_autoweighting: true
#   max_objective_weight: 0.999899983406
#   min_objective_weight: 9.99999974738e-05
# }
# training_config {
#   batch_size_per_gpu: 4
#   num_epochs: 120
#   learning_rate {
#     soft_start_annealing_schedule {
#       min_learning_rate: 5e-06
#       max_learning_rate: 5e-04
#       soft_start: 0.10000000149
#       annealing: 0.699999988079
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3.00000002618e-09
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
#   cost_scaling {
#     initial_exponent: 20.0
#     increment: 0.005
#     decrement: 1.0
#   }
#   checkpoint_interval: 10
# }
# bbox_rasterizer_config {
#   target_class_config {
#     key: "car"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 0.40000000596
#       cov_radius_y: 0.40000000596
#       bbox_min_radius: 1.0
#     }
#   }
#   target_class_config {
#     key: "cyclist"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   target_class_config {
#     key: "pedestrian"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   deadzone_radius: 0.400000154972
# }

# %% [markdown]
# ## 4. Run TAO training <a class="anchor" id="head-4"></a>
# * Provide the sample spec file and the output directory location for models
#
# *Note: The training may take hours to complete. Also, the remaining notebook, assumes that the training was done in single-GPU mode. When run in multi-GPU mode, please expect to update the pruning and inference steps with new pruning thresholds and updated parameters in the clusterfile.json accordingly for optimum performance.*
#
# *Detectnet_v2 now supports restart from checkpoint. In case the training job is killed prematurely, you may resume training from the closest checkpoint by simply re-running the **same** command line. Please do make sure to use the <u>**same number of GPUs**</u> when restarting the training.*
#
# *When running the training with NUM_GPUs>1, you may need to modify the `batch_size_per_gpu` and `learning_rate` to get similar mAP as a 1GPU training run. In most cases, scaling down the batch-size by a factor of NUM_GPU's or scaling up the learning rate by a factor of NUM_GPU's would be a good place to start.*

# %%
# !tao detectnet_v2 train -e $SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt \
                        -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
                        -k $KEY \
                        -n resnet18_detector \
                        --gpus $NUM_GPUS
# Out:
# 2022-04-07 12:11:42,666 [INFO] root: Registry: ['nvcr.io']
# 2022-04-07 12:11:42,801 [INFO] tlt.components.instance_handler.local_instance: Running command in container: nvcr.io/nvidia/tao/tao-toolkit-tf:v3.21.11-tf1.15.4-py3
# 2022-04-07 12:11:42,820 [WARNING] tlt.components.docker_handler.docker_handler:
# Docker will run the commands as root. If you would like to retain your
# local host permissions, please add the "user":"UID:GID" in the
# DockerOptions portion of the "/home/zosov/.tao_mounts.json" file. You can obtain your
# users UID and GID by using the "id -u" and "id -g" commands on the
# terminal.
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:43: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# 2022-04-07 17:11:54,922 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:43: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/checkpoint_saver_hook.py:25: The name tf.train.CheckpointSaverHook is deprecated. Please use tf.estimator.CheckpointSaverHook instead.
#
# 2022-04-07 17:11:55,104 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/checkpoint_saver_hook.py:25: The name tf.train.CheckpointSaverHook is deprecated. Please use tf.estimator.CheckpointSaverHook instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:69: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2022-04-07 17:11:55,107 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:69: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:69: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2022-04-07 17:11:55,108 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:69: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/horovod/tensorflow/__init__.py:117: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2022-04-07 17:11:55,120 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/horovod/tensorflow/__init__.py:117: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/horovod/tensorflow/__init__.py:143: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-04-07 17:11:55,120 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/horovod/tensorflow/__init__.py:143: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-04-07 17:11:55,999 [INFO] __main__: Loading experiment spec at /workspace/tao-experiments/detectnet_v2/specs/detectnet_v2_train_resnet18_kitti.txt.
# 2022-04-07 17:11:56,002 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /workspace/tao-experiments/detectnet_v2/specs/detectnet_v2_train_resnet18_kitti.txt
# 2022-04-07 17:11:57,003 [INFO] __main__: Cannot iterate over exactly 6434 samples with a batch size of 4; each epoch will therefore take one extra step.
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:107: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# 2022-04-07 17:11:57,007 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:107: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:110: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# 2022-04-07 17:11:57,008 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:110: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:113: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# 2022-04-07 17:11:57,012 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:113: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2022-04-07 17:11:57,159 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2022-04-07 17:11:57,161 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2022-04-07 17:11:57,201 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2022-04-07 17:11:59,506 [WARNING] tensorflow: From /opt/nvidia/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2022-04-07 17:12:00,062 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2022-04-07 17:12:00,063 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-04-07 17:12:00,722 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-04-07 17:12:12,464 [INFO] iva.detectnet_v2.objectives.bbox_objective: Default L1 loss function will be used.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 384, 1248) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 192, 624) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 192, 624) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 192, 624) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 96, 312)  36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 96, 312)  0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 96, 312)  36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 96, 312)  4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 96, 312)  256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 96, 312)  0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 96, 312)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 96, 312)  36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (None, 64, 96, 312)  256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 96, 312)  0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 96, 312)  36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (None, 64, 96, 312)  256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 96, 312)  0           block_1b_bn_2[0][0]
#                                                                  block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 96, 312)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 48, 156) 73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 48, 156) 0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 48, 156) 147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 48, 156) 8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 48, 156) 512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 48, 156) 0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 48, 156) 0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 48, 156) 147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (None, 128, 48, 156) 512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 48, 156) 0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 48, 156) 147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (None, 128, 48, 156) 512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 48, 156) 0           block_2b_bn_2[0][0]
#                                                                  block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 48, 156) 0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 24, 78)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 24, 78)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 24, 78)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 24, 78)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 24, 78)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 24, 78)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 256, 24, 78)  1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 24, 78)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 24, 78)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 24, 78)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (None, 256, 24, 78)  1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 24, 78)  0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 24, 78)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (None, 256, 24, 78)  1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 24, 78)  0           block_3b_bn_2[0][0]
#                                                                  block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 24, 78)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 24, 78)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 24, 78)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 24, 78)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 24, 78)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 24, 78)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 24, 78)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 512, 24, 78)  2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 24, 78)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 24, 78)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 24, 78)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (None, 512, 24, 78)  2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 24, 78)  0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 24, 78)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (None, 512, 24, 78)  2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 24, 78)  0           block_4b_bn_2[0][0]
#                                                                  block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 24, 78)  0           add_8[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 12, 24, 78)   6156        block_4b_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 3, 24, 78)    1539        block_4b_relu[0][0]
# ==================================================================================================
# Total params: 11,203,023
# Trainable params: 11,193,295
# Non-trainable params: 9,728
# __________________________________________________________________________________________________
# 2022-04-07 17:12:12,548 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2022-04-07 17:12:12,548 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2022-04-07 17:12:12,548 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): (0, 0)
# 2022-04-07 17:12:12,549 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 8, io threads: 16, compute threads: 8, buffered batches: 4
# 2022-04-07 17:12:12,549 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 6434, number of sources: 1, batch size per gpu: 4, steps: 1609
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2022-04-07 17:12:12,641 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179045f8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179045f8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:12,741 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179045f8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179045f8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:12,774 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2022-04-07 17:12:13,255 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# 2022-04-07 17:12:13,267 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 1 datasets with weights:
# 2022-04-07 17:12:13,267 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7ed07c1fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7ed07c1fd0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:13,291 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7ed07c1fd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7ed07c1fd0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:14,085 [INFO] __main__: Found 6434 samples in training set
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/rasterizers/bbox_rasterizer.py:347: The name tf.bincount is deprecated. Please use tf.math.bincount instead.
#
# 2022-04-07 17:12:14,312 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/rasterizers/bbox_rasterizer.py:347: The name tf.bincount is deprecated. Please use tf.math.bincount instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/training_proto_utilities.py:89: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# 2022-04-07 17:12:14,587 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/training_proto_utilities.py:89: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/training_proto_utilities.py:36: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# 2022-04-07 17:12:14,619 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/training_proto_utilities.py:36: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_functions.py:17: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2022-04-07 17:12:14,957 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_functions.py:17: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:235: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# 2022-04-07 17:12:15,051 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/cost_function/cost_auto_weight_hook.py:235: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/model/detectnet_model.py:591: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# 2022-04-07 17:12:15,070 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/model/detectnet_model.py:591: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# 2022-04-07 17:12:18,370 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2022-04-07 17:12:18,370 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2022-04-07 17:12:18,370 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): (0, 0)
# 2022-04-07 17:12:18,370 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 8, io threads: 16, compute threads: 8, buffered batches: 4
# 2022-04-07 17:12:18,371 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 1047, number of sources: 1, batch size per gpu: 4, steps: 262
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179046a0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179046a0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:18,389 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179046a0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x7f7f179046a0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:18,431 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2022-04-07 17:12:18,971 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# 2022-04-07 17:12:18,982 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 1 datasets with weights:
# 2022-04-07 17:12:18,983 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 1.000000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7e4ec97f60>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7e4ec97f60>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:19,012 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7e4ec97f60>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7f7e4ec97f60>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2022-04-07 17:12:19,526 [INFO] __main__: Found 1047 samples in validation set
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/validation_hook.py:40: The name tf.summary.FileWriterCache is deprecated. Please use tf.compat.v1.summary.FileWriterCache instead.
#
# 2022-04-07 17:12:20,632 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/validation_hook.py:40: The name tf.summary.FileWriterCache is deprecated. Please use tf.compat.v1.summary.FileWriterCache instead.
#
# 2022-04-07 17:12:22,607 [INFO] __main__: Checkpoint interval: 10
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:109: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# 2022-04-07 17:12:22,607 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/scripts/train.py:109: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:14: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# 2022-04-07 17:12:22,608 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:14: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:15: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# 2022-04-07 17:12:22,609 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:15: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:16: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# 2022-04-07 17:12:22,610 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:16: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:59: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# 2022-04-07 17:12:22,614 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:59: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:60: The name tf.train.StopAtStepHook is deprecated. Please use tf.estimator.StopAtStepHook instead.
#
# 2022-04-07 17:12:22,614 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:60: The name tf.train.StopAtStepHook is deprecated. Please use tf.estimator.StopAtStepHook instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:73: The name tf.train.StepCounterHook is deprecated. Please use tf.estimator.StepCounterHook instead.
#
# 2022-04-07 17:12:22,615 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:73: The name tf.train.StepCounterHook is deprecated. Please use tf.estimator.StepCounterHook instead.
#
# INFO:tensorflow:Create CheckpointSaverHook.
# 2022-04-07 17:12:22,615 [INFO] tensorflow: Create CheckpointSaverHook.
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:99: The name tf.train.SummarySaverHook is deprecated. Please use tf.estimator.SummarySaverHook instead.
#
# 2022-04-07 17:12:22,615 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/tfhooks/utils.py:99: The name tf.train.SummarySaverHook is deprecated. Please use tf.estimator.SummarySaverHook instead.
#
# WARNING:tensorflow:From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/utilities.py:140: The name tf.train.SingularMonitoredSession is deprecated. Please use tf.compat.v1.train.SingularMonitoredSession instead.
#
# 2022-04-07 17:12:22,616 [WARNING] tensorflow: From /opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/training/utilities.py:140: The name tf.train.SingularMonitoredSession is deprecated. Please use tf.compat.v1.train.SingularMonitoredSession instead.
#
# INFO:tensorflow:Graph was finalized.
# 2022-04-07 17:12:24,350 [INFO] tensorflow: Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2022-04-07 17:12:27,304 [INFO] tensorflow: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2022-04-07 17:12:28,319 [INFO] tensorflow: Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for step-0.
# 2022-04-07 17:12:39,730 [INFO] tensorflow: Saving checkpoints for step-0.
# INFO:tensorflow:epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.12865089, step = 0
# 2022-04-07 17:13:10,826 [INFO] tensorflow: epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.12865089, step = 0
# 2022-04-07 17:13:10,831 [INFO] iva.detectnet_v2.tfhooks.task_progress_monitor_hook: Epoch 0/30: loss: 0.12865 learning rate: 0.00000 Time taken: 0:00:00 ETA: 0:00:00
# 2022-04-07 17:13:10,831 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 0.503
# INFO:tensorflow:epoch = 0.0031075201988812924, learning_rate = 5.0239078e-06, loss = 0.12698688, step = 5 (5.562 sec)
# ...
# 2022-04-07 17:56:05,443 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.542
# INFO:tensorflow:epoch = 0.6376631448104412, learning_rate = 1.330696e-05, loss = 0.002192027, step = 1026 (8.564 sec)
# 2022-04-07 17:56:11,203 [INFO] tensorflow: epoch = 0.6376631448104412, learning_rate = 1.330696e-05, loss = 0.002192027, step = 1026 (8.564 sec)
# INFO:tensorflow:epoch = 0.63952765692977, learning_rate = 1.33450985e-05, loss = 0.0017569596, step = 1029 (8.574 sec)
# 2022-04-07 17:56:19,777 [INFO] tensorflow: epoch = 0.63952765692977, learning_rate = 1.33450985e-05, loss = 0.0017569596, step = 1029 (8.574 sec)
# INFO:tensorflow:epoch = 0.6413921690490988, learning_rate = 1.3383346e-05, loss = 0.0029284447, step = 1032 (8.546 sec)
# 2022-04-07 17:56:28,323 [INFO] tensorflow: epoch = 0.6413921690490988, learning_rate = 1.3383346e-05, loss = 0.0029284447, step = 1032 (8.546 sec)
# INFO:tensorflow:epoch = 0.6438781852082038, learning_rate = 1.3434523e-05, loss = 0.0029482043, step = 1036 (7.057 sec)
# 2022-04-07 17:56:35,380 [INFO] tensorflow: epoch = 0.6438781852082038, learning_rate = 1.3434523e-05, loss = 0.0029482043, step = 1036 (7.057 sec)
# INFO:tensorflow:epoch = 0.6469857054070851, learning_rate = 1.3498749e-05, loss = 0.0018314944, step = 1041 (10.295 sec)
# 2022-04-07 17:56:45,674 [INFO] tensorflow: epoch = 0.6469857054070851, learning_rate = 1.3498749e-05, loss = 0.0018314944, step = 1041 (10.295 sec)
# INFO:tensorflow:epoch = 0.6488502175264139, learning_rate = 1.353745e-05, loss = 0.0016347261, step = 1044 (8.423 sec)
# 2022-04-07 17:56:54,097 [INFO] tensorflow: epoch = 0.6488502175264139, learning_rate = 1.353745e-05, loss = 0.0016347261, step = 1044 (8.423 sec)
# INFO:tensorflow:epoch = 0.6507147296457426, learning_rate = 1.357625e-05, loss = 0.0015790621, step = 1047 (8.490 sec)
# 2022-04-07 17:57:02,587 [INFO] tensorflow: epoch = 0.6507147296457426, learning_rate = 1.357625e-05, loss = 0.0015790621, step = 1047 (8.490 sec)
# 2022-04-07 17:57:05,673 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.660
# INFO:tensorflow:epoch = 0.6538222498446239, learning_rate = 1.3641167e-05, loss = 0.0015810274, step = 1052 (7.439 sec)
# 2022-04-07 17:57:10,026 [INFO] tensorflow: epoch = 0.6538222498446239, learning_rate = 1.3641167e-05, loss = 0.0015810274, step = 1052 (7.439 sec)
# INFO:tensorflow:epoch = 0.6556867619639527, learning_rate = 1.3680264e-05, loss = 0.0024138684, step = 1055 (8.433 sec)
# 2022-04-07 17:57:18,459 [INFO] tensorflow: epoch = 0.6556867619639527, learning_rate = 1.3680264e-05, loss = 0.0024138684, step = 1055 (8.433 sec)
# INFO:tensorflow:epoch = 0.6575512740832815, learning_rate = 1.3719473e-05, loss = 0.0029716399, step = 1058 (8.213 sec)
# 2022-04-07 17:57:26,673 [INFO] tensorflow: epoch = 0.6575512740832815, learning_rate = 1.3719473e-05, loss = 0.0029716399, step = 1058 (8.213 sec)
# INFO:tensorflow:epoch = 0.6594157862026103, learning_rate = 1.3758794e-05, loss = 0.0016318479, step = 1061 (8.332 sec)
# 2022-04-07 17:57:35,005 [INFO] tensorflow: epoch = 0.6594157862026103, learning_rate = 1.3758794e-05, loss = 0.0016318479, step = 1061 (8.332 sec)
# INFO:tensorflow:epoch = 0.661280298321939, learning_rate = 1.3798227e-05, loss = 0.0017130817, step = 1064 (8.548 sec)
# 2022-04-07 17:57:43,553 [INFO] tensorflow: epoch = 0.661280298321939, learning_rate = 1.3798227e-05, loss = 0.0017130817, step = 1064 (8.548 sec)
# INFO:tensorflow:epoch = 0.6631448104412678, learning_rate = 1.3837787e-05, loss = 0.0016354762, step = 1067 (8.400 sec)
# 2022-04-07 17:57:51,953 [INFO] tensorflow: epoch = 0.6631448104412678, learning_rate = 1.3837787e-05, loss = 0.0016354762, step = 1067 (8.400 sec)
# INFO:tensorflow:epoch = 0.6650093225605966, learning_rate = 1.3877448e-05, loss = 0.0016845795, step = 1070 (8.658 sec)
# 2022-04-07 17:58:00,611 [INFO] tensorflow: epoch = 0.6650093225605966, learning_rate = 1.3877448e-05, loss = 0.0016845795, step = 1070 (8.658 sec)
# INFO:tensorflow:epoch = 0.6668738346799253, learning_rate = 1.3917222e-05, loss = 0.0016341921, step = 1073 (8.423 sec)
# 2022-04-07 17:58:09,035 [INFO] tensorflow: epoch = 0.6668738346799253, learning_rate = 1.3917222e-05, loss = 0.0016341921, step = 1073 (8.423 sec)
# 2022-04-07 17:58:11,844 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.511
# INFO:tensorflow:epoch = 0.6687383467992541, learning_rate = 1.3957108e-05, loss = 0.0016889998, step = 1076 (8.556 sec)
# 2022-04-07 17:58:17,590 [INFO] tensorflow: epoch = 0.6687383467992541, learning_rate = 1.3957108e-05, loss = 0.0016889998, step = 1076 (8.556 sec)
# INFO:tensorflow:epoch = 0.673088875077688, learning_rate = 1.40506345e-05, loss = 0.0016101953, step = 1083 (10.060 sec)
# 2022-04-07 17:58:27,651 [INFO] tensorflow: epoch = 0.673088875077688, learning_rate = 1.40506345e-05, loss = 0.0016101953, step = 1083 (10.060 sec)
# INFO:tensorflow:epoch = 0.6749533871970167, learning_rate = 1.4090904e-05, loss = 0.0016984583, step = 1086 (8.028 sec)
# 2022-04-07 17:58:35,678 [INFO] tensorflow: epoch = 0.6749533871970167, learning_rate = 1.4090904e-05, loss = 0.0016984583, step = 1086 (8.028 sec)
# INFO:tensorflow:epoch = 0.6768178993163455, learning_rate = 1.413129e-05, loss = 0.0017701773, step = 1089 (8.302 sec)
# 2022-04-07 17:58:43,980 [INFO] tensorflow: epoch = 0.6768178993163455, learning_rate = 1.413129e-05, loss = 0.0017701773, step = 1089 (8.302 sec)
# INFO:tensorflow:epoch = 0.6786824114356743, learning_rate = 1.4171792e-05, loss = 0.0019586983, step = 1092 (8.291 sec)
# 2022-04-07 17:58:52,271 [INFO] tensorflow: epoch = 0.6786824114356743, learning_rate = 1.4171792e-05, loss = 0.0019586983, step = 1092 (8.291 sec)
# INFO:tensorflow:epoch = 0.680546923555003, learning_rate = 1.4212423e-05, loss = 0.001907629, step = 1095 (8.194 sec)
# 2022-04-07 17:59:00,464 [INFO] tensorflow: epoch = 0.680546923555003, learning_rate = 1.4212423e-05, loss = 0.001907629, step = 1095 (8.194 sec)
# INFO:tensorflow:epoch = 0.6824114356743318, learning_rate = 1.4253157e-05, loss = 0.0014335343, step = 1098 (8.407 sec)
# 2022-04-07 17:59:08,872 [INFO] tensorflow: epoch = 0.6824114356743318, learning_rate = 1.4253157e-05, loss = 0.0014335343, step = 1098 (8.407 sec)
# 2022-04-07 17:59:11,605 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.673
# INFO:tensorflow:epoch = 0.6842759477936606, learning_rate = 1.4294007e-05, loss = 0.0018138178, step = 1101 (8.329 sec)
# 2022-04-07 17:59:17,201 [INFO] tensorflow: epoch = 0.6842759477936606, learning_rate = 1.4294007e-05, loss = 0.0018138178, step = 1101 (8.329 sec)
# INFO:tensorflow:epoch = 0.6861404599129894, learning_rate = 1.4334975e-05, loss = 0.0014994768, step = 1104 (8.601 sec)
# 2022-04-07 17:59:25,802 [INFO] tensorflow: epoch = 0.6861404599129894, learning_rate = 1.4334975e-05, loss = 0.0014994768, step = 1104 (8.601 sec)
# INFO:tensorflow:epoch = 0.6880049720323181, learning_rate = 1.437606e-05, loss = 0.0016194289, step = 1107 (8.512 sec)
# 2022-04-07 17:59:34,314 [INFO] tensorflow: epoch = 0.6880049720323181, learning_rate = 1.437606e-05, loss = 0.0016194289, step = 1107 (8.512 sec)
# INFO:tensorflow:epoch = 0.689869484151647, learning_rate = 1.4417263e-05, loss = 0.0019320197, step = 1110 (8.427 sec)
# 2022-04-07 17:59:42,741 [INFO] tensorflow: epoch = 0.689869484151647, learning_rate = 1.4417263e-05, loss = 0.0019320197, step = 1110 (8.427 sec)
# INFO:tensorflow:epoch = 0.6917339962709758, learning_rate = 1.4458585e-05, loss = 0.001863232, step = 1113 (8.478 sec)
# 2022-04-07 17:59:51,219 [INFO] tensorflow: epoch = 0.6917339962709758, learning_rate = 1.4458585e-05, loss = 0.001863232, step = 1113 (8.478 sec)
# INFO:tensorflow:epoch = 0.6935985083903045, learning_rate = 1.4500037e-05, loss = 0.0015351736, step = 1116 (8.433 sec)
# 2022-04-07 17:59:59,652 [INFO] tensorflow: epoch = 0.6935985083903045, learning_rate = 1.4500037e-05, loss = 0.0015351736, step = 1116 (8.433 sec)
# INFO:tensorflow:epoch = 0.6954630205096333, learning_rate = 1.4541596e-05, loss = 0.001644608, step = 1119 (8.402 sec)
# 2022-04-07 18:00:08,053 [INFO] tensorflow: epoch = 0.6954630205096333, learning_rate = 1.4541596e-05, loss = 0.001644608, step = 1119 (8.402 sec)
# INFO:tensorflow:global_step/sec: 0.400307
# 2022-04-07 18:00:09,172 [INFO] tensorflow: global_step/sec: 0.400307
# 2022-04-07 18:00:14,265 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.596
# INFO:tensorflow:epoch = 0.6991920447482908, learning_rate = 1.46250695e-05, loss = 0.0016398836, step = 1125 (7.561 sec)
# 2022-04-07 18:00:15,614 [INFO] tensorflow: epoch = 0.6991920447482908, learning_rate = 1.46250695e-05, loss = 0.0016398836, step = 1125 (7.561 sec)
# INFO:tensorflow:epoch = 0.7016780609073958, learning_rate = 1.4680994e-05, loss = 0.0016956461, step = 1129 (9.123 sec)
# 2022-04-07 18:00:24,737 [INFO] tensorflow: epoch = 0.7016780609073958, learning_rate = 1.4680994e-05, loss = 0.0016956461, step = 1129 (9.123 sec)
# INFO:tensorflow:epoch = 0.7035425730267246, learning_rate = 1.4723072e-05, loss = 0.001791212, step = 1132 (8.433 sec)
# 2022-04-07 18:00:33,170 [INFO] tensorflow: epoch = 0.7035425730267246, learning_rate = 1.4723072e-05, loss = 0.001791212, step = 1132 (8.433 sec)
# INFO:tensorflow:epoch = 0.7054070851460534, learning_rate = 1.4765268e-05, loss = 0.0025778925, step = 1135 (6.161 sec)
# 2022-04-07 18:00:39,332 [INFO] tensorflow: epoch = 0.7054070851460534, learning_rate = 1.4765268e-05, loss = 0.0025778925, step = 1135 (6.161 sec)
# INFO:tensorflow:epoch = 0.7085146053449347, learning_rate = 1.4835871e-05, loss = 0.002064755, step = 1140 (8.294 sec)
# 2022-04-07 18:00:47,625 [INFO] tensorflow: epoch = 0.7085146053449347, learning_rate = 1.4835871e-05, loss = 0.002064755, step = 1140 (8.294 sec)
# INFO:tensorflow:epoch = 0.7103791174642635, learning_rate = 1.4878392e-05, loss = 0.001595391, step = 1143 (8.549 sec)
# 2022-04-07 18:00:56,174 [INFO] tensorflow: epoch = 0.7103791174642635, learning_rate = 1.4878392e-05, loss = 0.001595391, step = 1143 (8.549 sec)
# INFO:tensorflow:epoch = 0.7122436295835922, learning_rate = 1.4921035e-05, loss = 0.0013828654, step = 1146 (8.521 sec)
# 2022-04-07 18:01:04,694 [INFO] tensorflow: epoch = 0.7122436295835922, learning_rate = 1.4921035e-05, loss = 0.0013828654, step = 1146 (8.521 sec)
# INFO:tensorflow:epoch = 0.714108141702921, learning_rate = 1.4963799e-05, loss = 0.0013829569, step = 1149 (8.496 sec)
# 2022-04-07 18:01:13,191 [INFO] tensorflow: epoch = 0.714108141702921, learning_rate = 1.4963799e-05, loss = 0.0013829569, step = 1149 (8.496 sec)
# 2022-04-07 18:01:13,192 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.697
# INFO:tensorflow:epoch = 0.7159726538222498, learning_rate = 1.5006701e-05, loss = 0.0013787746, step = 1152 (8.481 sec)
# 2022-04-07 18:01:21,671 [INFO] tensorflow: epoch = 0.7159726538222498, learning_rate = 1.5006701e-05, loss = 0.0013787746, step = 1152 (8.481 sec)
# INFO:tensorflow:epoch = 0.7178371659415785, learning_rate = 1.5049711e-05, loss = 0.0035796713, step = 1155 (8.704 sec)
# 2022-04-07 18:01:30,375 [INFO] tensorflow: epoch = 0.7178371659415785, learning_rate = 1.5049711e-05, loss = 0.0035796713, step = 1155 (8.704 sec)
# INFO:tensorflow:epoch = 0.7197016780609073, learning_rate = 1.5092845e-05, loss = 0.0019490931, step = 1158 (8.664 sec)
# 2022-04-07 18:01:39,039 [INFO] tensorflow: epoch = 0.7197016780609073, learning_rate = 1.5092845e-05, loss = 0.0019490931, step = 1158 (8.664 sec)
# INFO:tensorflow:epoch = 0.7215661901802362, learning_rate = 1.5136102e-05, loss = 0.0016237465, step = 1161 (8.918 sec)
# 2022-04-07 18:01:47,957 [INFO] tensorflow: epoch = 0.7215661901802362, learning_rate = 1.5136102e-05, loss = 0.0016237465, step = 1161 (8.918 sec)
# INFO:tensorflow:epoch = 0.7234307022995649, learning_rate = 1.5179483e-05, loss = 0.0014330165, step = 1164 (8.507 sec)
# 2022-04-07 18:01:56,464 [INFO] tensorflow: epoch = 0.7234307022995649, learning_rate = 1.5179483e-05, loss = 0.0014330165, step = 1164 (8.507 sec)
# INFO:tensorflow:epoch = 0.7252952144188937, learning_rate = 1.5222989e-05, loss = 0.0019184535, step = 1167 (8.403 sec)
# 2022-04-07 18:02:04,867 [INFO] tensorflow: epoch = 0.7252952144188937, learning_rate = 1.5222989e-05, loss = 0.0019184535, step = 1167 (8.403 sec)
# INFO:tensorflow:epoch = 0.7284027346177749, learning_rate = 1.529578e-05, loss = 0.0021081204, step = 1172 (6.143 sec)
# 2022-04-07 18:02:11,010 [INFO] tensorflow: epoch = 0.7284027346177749, learning_rate = 1.529578e-05, loss = 0.0021081204, step = 1172 (6.143 sec)
# 2022-04-07 18:02:13,479 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.659
# INFO:tensorflow:epoch = 0.7315102548166562, learning_rate = 1.536892e-05, loss = 0.0016224545, step = 1177 (8.832 sec)
# 2022-04-07 18:02:19,842 [INFO] tensorflow: epoch = 0.7315102548166562, learning_rate = 1.536892e-05, loss = 0.0016224545, step = 1177 (8.832 sec)
# INFO:tensorflow:epoch = 0.733374766935985, learning_rate = 1.5412968e-05, loss = 0.0014892638, step = 1180 (8.465 sec)
# 2022-04-07 18:02:28,307 [INFO] tensorflow: epoch = 0.733374766935985, learning_rate = 1.5412968e-05, loss = 0.0014892638, step = 1180 (8.465 sec)
# INFO:tensorflow:epoch = 0.7352392790553138, learning_rate = 1.5457157e-05, loss = 0.0017564127, step = 1183 (8.639 sec)
# 2022-04-07 18:02:36,946 [INFO] tensorflow: epoch = 0.7352392790553138, learning_rate = 1.5457157e-05, loss = 0.0017564127, step = 1183 (8.639 sec)
# INFO:tensorflow:epoch = 0.7383467992541951, learning_rate = 1.553107e-05, loss = 0.0013281739, step = 1188 (7.447 sec)
# 2022-04-07 18:02:44,394 [INFO] tensorflow: epoch = 0.7383467992541951, learning_rate = 1.553107e-05, loss = 0.0013281739, step = 1188 (7.447 sec)
# INFO:tensorflow:epoch = 0.7408328154133001, learning_rate = 1.5590444e-05, loss = 0.0016194929, step = 1192 (9.915 sec)
# 2022-04-07 18:02:54,309 [INFO] tensorflow: epoch = 0.7408328154133001, learning_rate = 1.5590444e-05, loss = 0.0016194929, step = 1192 (9.915 sec)
# INFO:tensorflow:epoch = 0.742697327532629, learning_rate = 1.5635127e-05, loss = 0.0018553622, step = 1195 (9.262 sec)
# 2022-04-07 18:03:03,571 [INFO] tensorflow: epoch = 0.742697327532629, learning_rate = 1.5635127e-05, loss = 0.0018553622, step = 1195 (9.262 sec)
# INFO:tensorflow:epoch = 0.7445618396519577, learning_rate = 1.5679938e-05, loss = 0.0014441209, step = 1198 (8.464 sec)
# 2022-04-07 18:03:12,034 [INFO] tensorflow: epoch = 0.7445618396519577, learning_rate = 1.5679938e-05, loss = 0.0014441209, step = 1198 (8.464 sec)
# 2022-04-07 18:03:14,856 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 1.629
# INFO:tensorflow:epoch = 0.7464263517712865, learning_rate = 1.5724878e-05, loss = 0.001989623, step = 1201 (9.078 sec)
# 2022-04-07 18:03:21,113 [INFO] tensorflow: epoch = 0.7464263517712865, learning_rate = 1.5724878e-05, loss = 0.001989623, step = 1201 (9.078 sec)
# INFO:tensorflow:epoch = 0.7482908638906153, learning_rate = 1.5769961e-05, loss = 0.0012830434, step = 1204 (9.359 sec)
# 2022-04-07 18:03:30,472 [INFO] tensorflow: epoch = 0.7482908638906153, learning_rate = 1.5769961e-05, loss = 0.0012830434, step = 1204 (9.359 sec)
# ^C
# Traceback (most recent call last):
#   File "/usr/local/bin/detectnet_v2", line 8, in <module>
#     sys.exit(main())
#   File "/opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/entrypoint/detectnet_v2.py", line 12, in main
#   File "/opt/tlt/.cache/dazel/_dazel_tlt/75913d2aee35770fa76c4a63d877f3aa/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/common/entrypoint/entrypoint.py", line 339, in launch_job
#   File "/usr/lib/python3.6/subprocess.py", line 306, in check_call
#     retcode = call(*popenargs, **kwargs)
#   File "/usr/lib/python3.6/subprocess.py", line 289, in call
#     return p.wait(timeout=timeout)
#   File "/usr/lib/python3.6/subprocess.py", line 1477, in wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.6/subprocess.py", line 1424, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)

# %%
print('Model for each epoch:')
print('---------------------')
# !ls -lh $LOCAL_EXPERIMENT_DIR/experiment_dir_unpruned/weights

# %% [markdown]
# ## 5. Evaluate the trained model <a class="anchor" id="head-5"></a>

# %%
# !tao detectnet_v2 evaluate -e $SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt\
                           -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/resnet18_detector.tlt \
                           -k $KEY

# %% [markdown]
# ## 6. Prune the trained model <a class="anchor" id="head-6"></a>
# * Specify pre-trained model
# * Equalization criterion (`Applicable for resnets and mobilenets`)
# * Threshold for pruning.
# * A key to save and load the model
# * Output directory to store the model
#
# *Usually, you just need to adjust `-pth` (threshold) for accuracy and model size trade off. Higher `pth` gives you smaller model (and thus higher inference speed) but worse accuracy. The threshold to use is dependent on the dataset. A pth value `5.2e-6` is just a start point. If the retrain accuracy is good, you can increase this value to get smaller models. Otherwise, lower this value to get better accuracy.*
#
# *For some internal studies, we have noticed that a pth value of 0.01 is a good starting point for detectnet_v2 models.*

# %%
# Create an output directory if it doesn't exist.
# !mkdir -p $LOCAL_EXPERIMENT_DIR/experiment_dir_pruned

# %%
# !tao detectnet_v2 prune \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/resnet18_detector.tlt \
                  -o $USER_EXPERIMENT_DIR/experiment_dir_pruned/resnet18_nopool_bn_detectnet_v2_pruned.tlt \
                  -eq union \
                  -pth 0.0000052 \
                  -k $KEY

# %%
# !ls -rlt $LOCAL_EXPERIMENT_DIR/experiment_dir_pruned/

# %% [markdown]
# ## 7. Retrain the pruned model <a class="anchor" id="head-7"></a>
# * Model needs to be re-trained to bring back accuracy after pruning
# * Specify re-training specification with pretrained weights as pruned model.
#
# *Note: For retraining, please set the `load_graph` option to `true` in the model_config to load the pruned model graph. Also, if after retraining, the model shows some decrease in mAP, it could be that the originally trained model was pruned a little too much. Please try reducing the pruning threshold (thereby reducing the pruning ratio) and use the new model to retrain.*
#
# *Note: DetectNet_v2 now supports Quantization Aware Training, to help with optmizing the model. By default, the training in the cell below doesn't run the model with QAT enabled. For information on training a model with QAT, please refer to the cells under [section 11](#head-11)*

# %%
# Printing the retrain experiment file. 
# Note: We have updated the experiment file to include the 
# newly pruned model as a pretrained weights and, the
# load_graph option is set to true 
# !cat $LOCAL_SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt

# %%
# Retraining using the pruned model as pretrained weights 
# !tao detectnet_v2 train -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt \
                        -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
                        -k $KEY \
                        -n resnet18_detector_pruned \
                        --gpus $NUM_GPUS

# %%
# Listing the newly retrained model.
# !ls -rlt $LOCAL_EXPERIMENT_DIR/experiment_dir_retrain/weights

# %% [markdown]
# ## 8. Evaluate the retrained model <a class="anchor" id="head-8"></a>

# %% [markdown]
# This section evaluates the pruned and retrained model, using the `evaluate` command.

# %%
# !tao detectnet_v2 evaluate -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt \
                           -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
                           -k $KEY

# %% [markdown]
# ## 9. Visualize inferences <a class="anchor" id="head-9"></a>
# In this section, we run the `inference` tool to generate inferences on the trained models. To render bboxes from more classes, please edit the spec file `detectnet_v2_inference_kitti_tlt.txt` to include all the classes you would like to visualize and edit the rest of the file accordingly.

# %%
# Running inference for detection on n images
# !tao detectnet_v2 inference -e $SPECS_DIR/detectnet_v2_inference_kitti_tlt.txt \
                            -o $USER_EXPERIMENT_DIR/tlt_infer_testing \
                            -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                            -k $KEY

# %% [markdown]
# The `inference` tool produces two outputs.
# 1. Overlain images in `$USER_EXPERIMENT_DIR/tlt_infer_testing/images_annotated`
# 2. Frame by frame bbox labels in kitti format located in `$USER_EXPERIMENT_DIR/tlt_infer_testing/labels`
#
# *Note: To run inferences for a single image, simply replace the path to the -i flag in `inference` command with the path to the image.*

# %%
# Simple grid visualizer
# !pip3 install matplotlib==3.3.3
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['LOCAL_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx // num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the first 12 images.
OUTPUT_PATH = 'tlt_infer_testing/images_annotated' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 10. Model Export <a class="anchor" id="head-10"></a>

# %%
# !mkdir -p $LOCAL_EXPERIMENT_DIR/experiment_dir_final
# Removing a pre-existing copy of the etlt if there has been any.
import os
output_file=os.path.join(os.environ['LOCAL_EXPERIMENT_DIR'],
                         "experiment_dir_final/resnet18_detector.etlt")
if os.path.exists(output_file):
    os.system("rm {}".format(output_file))
# !tao detectnet_v2 export \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
                  -o $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
                  -k $KEY

# %%
print('Exported model:')
print('------------')
# !ls -lh $LOCAL_EXPERIMENT_DIR/experiment_dir_final

# %% [markdown]
# ### A. Int8 Optimization <a class="anchor" id="head-10-1"></a>
# DetectNet_v2 model supports int8 inference mode in TensorRT.
# In order to use int8 mode, we must calibrate the model to run 8-bit inferences -
#
# * Generate calibration tensorfile from the training data using detectnet_v2 calibration_tensorfile
# * Use tao <task> export to generate int8 calibration table.
#
# *Note: For this example, we generate a calibration tensorfile containing 10 batches of training data.
# Ideally, it is best to use at least 10-20% of the training data to do so. The more data provided during calibration, the closer int8 inferences are to fp32 inferences.*
#
# *Note: If the model was trained with QAT nodes available, please refrain from using the post training int8 optimization as mentioned below. Please export the model in int8 mode (using the arg `--data_type int8`) with just the path to the calibration cache file (using the argument `--cal_cache_file`)*

# %%
# !tao detectnet_v2 calibration_tensorfile -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt \
                                         -m 10 \
                                         -o $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.tensor

# %%
# !rm -rf $LOCAL_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt
# !rm -rf $LOCAL_EXPERIMENT_DIR/experiment_dir_final/calibration.bin
# !tao detectnet_v2 export \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
                  -o $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
                  -k $KEY  \
                  --cal_data_file $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.tensor \
                  --data_type int8 \
                  --batches 10 \
                  --batch_size 4 \
                  --max_batch_size 4\
                  --engine_file $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.trt.int8 \
                  --cal_cache_file $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.bin \
                  --verbose

# %% [markdown]
# ### B. Generate TensorRT engine <a class="anchor" id="head-10-2"></a>
# Verify engine generation using the `tao-converter` utility included with the docker.
#
# The `tao-converter` produces optimized tensorrt engines for the platform that it resides on. Therefore, to get maximum performance, please instantiate this docker and execute the `tao-converter` command, with the exported `.etlt` file and calibration cache (for int8 mode) on your target device. The tao-converter utility included in this docker only works for x86 devices, with discrete NVIDIA GPU's.
#
# For the jetson devices, please download the tao-converter for jetson from the dev zone link [here](https://developer.nvidia.com/tao-converter).
#
# If you choose to integrate your model into deepstream directly, you may do so by simply copying the exported `.etlt` file along with the calibration cache to the target device and updating the spec file that configures the `gst-nvinfer` element to point to this newly exported model. Usually this file is called `config_infer_primary.txt` for detection models and `config_infer_secondary_*.txt` for classification models.

# %%
# !tao converter $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
                   -k $KEY \
                    -c $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.bin \
                   -o output_cov/Sigmoid,output_bbox/BiasAdd \
                   -d 3,384,1248 \
                   -i nchw \
                   -m 64 \
                   -t int8 \
                   -e $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.trt \
                   -b 4

# %% [markdown]
# ## 11. Verify Deployed Model <a class="anchor" id="head-11"></a>
# Verify the exported model by visualizing inferences on TensorRT.
# In addition to running inference on a `.tlt` model in [step 9](#head-9), the `inference` tool is also capable of consuming the converted `TensorRT engine` from [step 10.B](#head-10-2).
#
# *If after int-8 calibration the accuracy of the int-8 inferences seem to degrade, it could be because the there wasn't enough data in the calibration tensorfile used to calibrate thee model or, the training data is not entirely representative of your test images, and the calibration maybe incorrect. Therefore, you may either regenerate the calibration tensorfile with more batches of the training data and recalibrate the model, or calibrate the model on a few images from the test set. This may be done using `--cal_image_dir` flag in the `export` tool. For more information, please follow the instructions in the USER GUIDE.

# %% [markdown]
# ### A. Inference using TensorRT engine <a class="anchor" id="head-11-1"></a>

# %%
# !tao detectnet_v2 inference -e $SPECS_DIR/detectnet_v2_inference_kitti_etlt.txt \
                            -o $USER_EXPERIMENT_DIR/etlt_infer_testing \
                            -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                            -k $KEY

# %%
# visualize the first 12 inferenced images.
OUTPUT_PATH = 'etlt_infer_testing/images_annotated' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 11. QAT workflow <a class="anchor" id="head-12"></a>
# This section delves into the newly enabled Quantization Aware Training feature with DetectNet_v2. The workflow defined below converts a pruned model from section [5](#head-5) to enable QAT and retrain this model to while accounting the noise introduced due to quantization in the forward pass.

# %% [markdown]
# ### A. Convert pruned model to QAT and retrain <a class="anchor" id="head-12-1"></a>
# All detectnet models, unpruned and pruned models can be converted to QAT models by setting the `enable_qat` parameter in the `training_config` component of the spec file to `true`.

# %%
# Printing the retrain experiment file. 
# Note: We have updated the experiment file to convert the
# pretrained model to qat mode by setting the enable_qat
# parameter.
# !cat $LOCAL_SPECS_DIR/detectnet_v2_retrain_resnet18_kitti_qat.txt

# %%
# !tao detectnet_v2 train -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti_qat.txt \
                        -r $USER_EXPERIMENT_DIR/experiment_dir_retrain_qat \
                        -k $KEY \
                        -n resnet18_detector_pruned_qat \
                        --gpus $NUM_GPUS

# %%
# !ls -rlt $LOCAL_EXPERIMENT_DIR/experiment_dir_retrain_qat/weights

# %% [markdown]
# ### B. Evaluate QAT converted model <a class="anchor" id="head-12-2"></a>
# This section evaluates a QAT enabled pruned retrained model. The mAP of this model should be comparable to that of the pruned retrained model without QAT. However, due to quantization, it is possible sometimes to see a drop in the mAP value for certain datasets.

# %%
# !tao detectnet_v2 evaluate -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti_qat.txt \
                           -m $USER_EXPERIMENT_DIR/experiment_dir_retrain_qat/weights/resnet18_detector_pruned_qat.tlt \
                           -k $KEY \
                           -f tlt

# %% [markdown]
# ### C. Export QAT trained model to int8 <a class="anchor" id="head-12-3"></a>
# Export a QAT trained model to TensorRT parsable model. This command generates an .etlt file from the trained model and the serializes corresponding int8 scales as a TRT readable calibration cache file.

# %%
# !rm -rf $LOCAL_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector_qat.etlt
# !rm -rf $LOCAL_EXPERIMENT_DIR/experiment_dir_final/calibration_qat.bin
# !tao detectnet_v2 export \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain_qat/weights/resnet18_detector_pruned_qat.tlt \
                  -o $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector_qat.etlt \
                  -k $KEY  \
                  --data_type int8 \
                  --batch_size 64 \
                  --max_batch_size 64\
                  --engine_file $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector_qat.trt.int8 \
                  --cal_cache_file $USER_EXPERIMENT_DIR/experiment_dir_final/calibration_qat.bin \
                  --verbose

# %% [markdown]
# ### D. Evaluate a QAT trained model using the exported TensorRT engine <a class="anchor" id="head-12-4"></a>
# This section evaluates a QAT enabled pruned retrained model using the TensorRT int8 engine that was exported in [Section C](#head-12-3). Please note that there maybe a slight difference (~0.1-0.5%) in the mAP from [Section B](#head-12-2), oweing to some differences in the implementation of quantization in TensorRT.
#
# *Note: The TensorRT evaluator might be slightly slower than the TAO evaluator here, because the evaluation dataloader is pinned to the CPU to avoid any clashes between TensorRT and TAO instances in the GPU. Please note that this tool was not intended and has not been developed for profiling the model. It is just a means to qualitatively analyse the model.*
#
# *Please use native TensorRT or DeepStream for the most optimized inferences.*

# %%
# !tao detectnet_v2 evaluate -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti_qat.txt \
                           -m $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector_qat.trt.int8 \
                           -f tensorrt

# %% [markdown]
# ### E. Inference using QAT engine <a class="anchor" id="head-12-5"></a>
# Run inference and visualize detections on test images, using the exported TensorRT engine from [Section C](#head-12-3).

# %%
# !tao detectnet_v2 inference -e $SPECS_DIR/detectnet_v2_inference_kitti_etlt_qat.txt \
                            -o $USER_EXPERIMENT_DIR/tlt_infer_testing_qat \
                            -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                            -k $KEY

# %%
# visualize the first 12 inferenced images.
OUTPUT_PATH = 'tlt_infer_testing_qat/images_annotated' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)
